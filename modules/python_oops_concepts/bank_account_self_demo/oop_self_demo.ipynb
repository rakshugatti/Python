# %%
class Demo:

    def show():   # forgot self
        print("Hello")

obj = Demo()
obj.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4         print("Hello")
#       6 obj = Demo()
# ----> 7 obj.show()
#
# TypeError: Demo.show() takes 0 positional arguments but 1 was given

# %%
class Demo:

    def show(self):
        print("Hello")#corrected the code by adding self

obj = Demo()
obj.show()
# Out:
# Hello
